# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key +"&q="

# %%
lat = []
temp = []
city_name = []
country = []
humidity = []
cloudiness = []
windspeed = []

print("Data Retrieval")

row_count = 0


for city in cities:
    query_url = url + city
    response = requests.get(query_url).json()
    if response["cod"] == "404":
        print("No city record found.")
    else:
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        city_name.append(response['name'])
        country.append(response['sys']['country'])
        humidity.append(response['main']['humidity'])
        windspeed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
    
    print("-------------------------------------------------------------------------------")
    try:
        print("Processing: Record # " , row_count, ' | ' , response["name"],',', response['sys']['country'],'|' , response["id"])
        print(query_url)
    except KeyError: 
        print("Processing: Record # " , row_count, ' | ' , " City name not found (N/A)")
        print(query_url)
        
    
    row_count += 1
    
print("---------------------------------------------------")    
print("Data Retrieval Complete")
print("---------------------------------------------------")
# Out:
# Data Retrieval
# -------------------------------------------------------------------------------
# Processing: Record #  0  |  Avarua ,  CK | 4035715
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=avarua
# -------------------------------------------------------------------------------
# Processing: Record #  1  |  Cherskiy ,  RU | 2126199
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=cherskiy
# -------------------------------------------------------------------------------
# Processing: Record #  2  |  Tasiilaq ,  GL | 3424607
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=tasiilaq
# -------------------------------------------------------------------------------
# Processing: Record #  3  |  Baghdad ,  IQ | 98182
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=baghdad
# -------------------------------------------------------------------------------
# Processing: Record #  4  |  Hede ,  SE | 2720382
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hede
# -------------------------------------------------------------------------------
# Processing: Record #  5  |  San Patricio ,  PY | 3437029
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=san patricio
# -------------------------------------------------------------------------------
# Processing: Record #  6  |  Kavieng ,  PG | 2094342
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kavieng
# -------------------------------------------------------------------------------
# Processing: Record #  7  |  Hithadhoo ,  MV | 1282256
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hithadhoo
# -------------------------------------------------------------------------------
# Processing: Record #  8  |  Codrington ,  AU | 2160063
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=codrington
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  9  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=nizhneyansk
# -------------------------------------------------------------------------------
# Processing: Record #  10  |  Punta Arenas ,  CL | 3874787
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=punta arenas
# -------------------------------------------------------------------------------
# Processing: Record #  11  |  Atuona ,  PF | 4020109
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=atuona
# -------------------------------------------------------------------------------
# Processing: Record #  12  |  Lorengau ,  PG | 2092164
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=lorengau
# -------------------------------------------------------------------------------
# Processing: Record #  13  |  Puerto Ayora ,  EC | 3652764
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=puerto ayora
# -------------------------------------------------------------------------------
# Processing: Record #  14  |  College ,  US | 5859699
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=college
# -------------------------------------------------------------------------------
# Processing: Record #  15  |  Bredasdorp ,  ZA | 1015776
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=bredasdorp
# -------------------------------------------------------------------------------
# Processing: Record #  16  |  Mataura ,  NZ | 6201424
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mataura
# -------------------------------------------------------------------------------
# Processing: Record #  17  |  Chegdomyn ,  RU | 2025579
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=chegdomyn
# -------------------------------------------------------------------------------
# Processing: Record #  18  |  Douglas ,  US | 5554072
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=douglas
# -------------------------------------------------------------------------------
# Processing: Record #  19  |  Mahebourg ,  MU | 934322
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mahebourg
# -------------------------------------------------------------------------------
# Processing: Record #  20  |  Cabo San Lucas ,  MX | 3985710
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=cabo san lucas
# -------------------------------------------------------------------------------
# Processing: Record #  21  |  Port Macquarie ,  AU | 2152659
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=port macquarie
# -------------------------------------------------------------------------------
# Processing: Record #  22  |  Gorodets ,  RU | 559678
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=gorodets
# -------------------------------------------------------------------------------
# Processing: Record #  23  |  Tuatapere ,  NZ | 2180815
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=tuatapere
# -------------------------------------------------------------------------------
# Processing: Record #  24  |  Albany ,  US | 5106834
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=albany
# -------------------------------------------------------------------------------
# Processing: Record #  25  |  Rikitea ,  PF | 4030556
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=rikitea
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  26  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=barentsburg
# -------------------------------------------------------------------------------
# Processing: Record #  27  |  Sadri ,  IN | 1257865
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=sadri
# -------------------------------------------------------------------------------
# Processing: Record #  28  |  Clyde River ,  CA | 5924351
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=clyde river
# -------------------------------------------------------------------------------
# Processing: Record #  29  |  New Norfolk ,  AU | 2155415
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=new norfolk
# -------------------------------------------------------------------------------
# Processing: Record #  30  |  Kapaa ,  US | 5848280
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kapaa
# -------------------------------------------------------------------------------
# Processing: Record #  31  |  Busselton ,  AU | 2075265
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=busselton
# -------------------------------------------------------------------------------
# Processing: Record #  32  |  Carnarvon ,  ZA | 1014034
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=carnarvon
# -------------------------------------------------------------------------------
# Processing: Record #  33  |  Saskylakh ,  RU | 2017155
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=saskylakh
# -------------------------------------------------------------------------------
# Processing: Record #  34  |  Bluff ,  AU | 2175403
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=bluff
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  35  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=umzimvubu
# -------------------------------------------------------------------------------
# Processing: Record #  36  |  Vakhrushev ,  RU | 2119964
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=vakhrushev
# -------------------------------------------------------------------------------
# Processing: Record #  37  |  Itarema ,  BR | 3393692
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=itarema
# -------------------------------------------------------------------------------
# Processing: Record #  38  |  Talnakh ,  RU | 1490256
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=talnakh
# -------------------------------------------------------------------------------
# Processing: Record #  39  |  Ushuaia ,  AR | 3833367
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ushuaia
# -------------------------------------------------------------------------------
# Processing: Record #  40  |  Bang Saphan ,  TH | 1157662
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=bang saphan
# -------------------------------------------------------------------------------
# Processing: Record #  41  |  Sept-Iles ,  CA | 6144312
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=sept-iles
# -------------------------------------------------------------------------------
# Processing: Record #  42  |  Chokurdakh ,  RU | 2126123
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=chokurdakh
# -------------------------------------------------------------------------------
# Processing: Record #  43  |  Airai ,  TL | 1651810
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=airai
# -------------------------------------------------------------------------------
# Processing: Record #  44  |  Torbay ,  CA | 6167817
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=torbay
# -------------------------------------------------------------------------------
# Processing: Record #  45  |  Hervey Bay ,  AU | 2146219
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hervey bay
# -------------------------------------------------------------------------------
# Processing: Record #  46  |  Palmer ,  AU | 2067070
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=palmer
# -------------------------------------------------------------------------------
# Processing: Record #  47  |  Hasaki ,  JP | 2112802
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hasaki
# -------------------------------------------------------------------------------
# Processing: Record #  48  |  Grand Gaube ,  MU | 934479
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=grand gaube
# -------------------------------------------------------------------------------
# Processing: Record #  49  |  Barrow ,  AR | 3833859
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=barrow
# -------------------------------------------------------------------------------
# Processing: Record #  50  |  Lebu ,  ET | 344979
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=lebu
# -------------------------------------------------------------------------------
# Processing: Record #  51  |  Faanui ,  PF | 4034551
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=faanui
# -------------------------------------------------------------------------------
# Processing: Record #  52  |  Teahupoo ,  PF | 4033543
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=teahupoo
# -------------------------------------------------------------------------------
# Processing: Record #  53  |  Tautira ,  PF | 4033557
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=tautira
# -------------------------------------------------------------------------------
# Processing: Record #  54  |  Sagua la Grande ,  CU | 3541440
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=sagua la grande
# -------------------------------------------------------------------------------
# Processing: Record #  55  |  Flinders ,  AU | 6255012
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=flinders
# -------------------------------------------------------------------------------
# Processing: Record #  56  |  Bandarbeyla ,  SO | 64814
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=bandarbeyla
# -------------------------------------------------------------------------------
# Processing: Record #  57  |  Ayios Ioannis ,  CY | 146669
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ayios ioannis
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  58  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=illoqqortoormiut
# -------------------------------------------------------------------------------
# Processing: Record #  59  |  Northam ,  GB | 2641434
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=northam
# -------------------------------------------------------------------------------
# Processing: Record #  60  |  Poum ,  MK | 787487
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=poum
# -------------------------------------------------------------------------------
# Processing: Record #  61  |  Praia da Vitoria ,  PT | 3372760
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=praia da vitoria
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  62  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=maneadero
# -------------------------------------------------------------------------------
# Processing: Record #  63  |  Thompson ,  CA | 6165406
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=thompson
# -------------------------------------------------------------------------------
# Processing: Record #  64  |  Berlevag ,  NO | 780687
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=berlevag
# -------------------------------------------------------------------------------
# Processing: Record #  65  |  Chara ,  GR | 262462
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=chara
# -------------------------------------------------------------------------------
# Processing: Record #  66  |  Rio Cuarto ,  AR | 3838874
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=rio cuarto
# -------------------------------------------------------------------------------
# Processing: Record #  67  |  Rampura ,  IN | 1258592
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=rampura
# -------------------------------------------------------------------------------
# Processing: Record #  68  |  Xiongyue ,  CN | 2033630
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=xiongyue
# -------------------------------------------------------------------------------
# Processing: Record #  69  |  Pisco ,  PE | 3932145
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=pisco
# -------------------------------------------------------------------------------
# Processing: Record #  70  |  Georgetown ,  GY | 3378644
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=georgetown
# -------------------------------------------------------------------------------
# Processing: Record #  71  |  Doha ,  QA | 290030
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=doha
# -------------------------------------------------------------------------------
# Processing: Record #  72  |  Nikolskoye ,  RU | 546105
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=nikolskoye
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  73  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=belushya guba
# -------------------------------------------------------------------------------
# Processing: Record #  74  |  Narsaq ,  GL | 3421719
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=narsaq
# -------------------------------------------------------------------------------
# Processing: Record #  75  |  Borsad ,  IN | 1275230
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=borsad
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  76  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=tsihombe
# -------------------------------------------------------------------------------
# Processing: Record #  77  |  Banyo ,  CM | 2234794
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=banyo
# -------------------------------------------------------------------------------
# Processing: Record #  78  |  Urengoy ,  RU | 1488414
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=urengoy
# -------------------------------------------------------------------------------
# Processing: Record #  79  |  Tungor ,  RU | 2120400
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=tungor
# -------------------------------------------------------------------------------
# Processing: Record #  80  |  Xingtai ,  CN | 1788927
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=xingtai
# -------------------------------------------------------------------------------
# Processing: Record #  81  |  Ugoofaaru ,  MV | 1337619
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ugoofaaru
# -------------------------------------------------------------------------------
# Processing: Record #  82  |  Hobart ,  AU | 2163355
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hobart
# -------------------------------------------------------------------------------
# Processing: Record #  83  |  Oranjemund ,  ZA | 3354071
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=oranjemund
# -------------------------------------------------------------------------------
# Processing: Record #  84  |  Buala ,  SB | 2109528
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=buala
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  85  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=paradwip
# -------------------------------------------------------------------------------
# Processing: Record #  86  |  Butaritari ,  KI | 2110227
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=butaritari
# -------------------------------------------------------------------------------
# Processing: Record #  87  |  Mount Pleasant ,  US | 4712933
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mount pleasant
# -------------------------------------------------------------------------------
# Processing: Record #  88  |  Gusau ,  NG | 2339937
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=gusau
# -------------------------------------------------------------------------------
# Processing: Record #  89  |  Chuy ,  UY | 3443061
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=chuy
# -------------------------------------------------------------------------------
# Processing: Record #  90  |  Hammerfest ,  NO | 779683
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hammerfest
# -------------------------------------------------------------------------------
# Processing: Record #  91  |  Port Alfred ,  ZA | 964432
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=port alfred
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  92  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=grajau
# -------------------------------------------------------------------------------
# Processing: Record #  93  |  Kalabo ,  ZM | 915471
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kalabo
# -------------------------------------------------------------------------------
# Processing: Record #  94  |  Chihuahua ,  MX | 4014338
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=chihuahua
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  95  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=taolanaro
# -------------------------------------------------------------------------------
# Processing: Record #  96  |  Kyaikto ,  MM | 1317375
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kyaikto
# -------------------------------------------------------------------------------
# Processing: Record #  97  |  Kuytun ,  RU | 2021093
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kuytun
# -------------------------------------------------------------------------------
# Processing: Record #  98  |  Amahai ,  ID | 1651591
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=amahai
# -------------------------------------------------------------------------------
# Processing: Record #  99  |  Vostok ,  RU | 2013279
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=vostok
# -------------------------------------------------------------------------------
# Processing: Record #  100  |  Russell ,  AR | 3844421
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=russell
# -------------------------------------------------------------------------------
# Processing: Record #  101  |  Dunedin ,  NZ | 2191562
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=dunedin
# -------------------------------------------------------------------------------
# Processing: Record #  102  |  Abu Kamal ,  SY | 174448
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=abu kamal
# -------------------------------------------------------------------------------
# Processing: Record #  103  |  Baillif ,  GP | 3579761
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=baillif
# -------------------------------------------------------------------------------
# Processing: Record #  104  |  Hilo ,  US | 5855927
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hilo
# -------------------------------------------------------------------------------
# Processing: Record #  105  |  Hermanus ,  ZA | 3366880
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hermanus
# -------------------------------------------------------------------------------
# Processing: Record #  106  |  Monteagudo ,  BO | 3910094
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=monteagudo
# -------------------------------------------------------------------------------
# Processing: Record #  107  |  Vaini ,  IN | 1273574
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=vaini
# -------------------------------------------------------------------------------
# Processing: Record #  108  |  Pevek ,  RU | 2122090
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=pevek
# -------------------------------------------------------------------------------
# Processing: Record #  109  |  Ribas do Rio Pardo ,  BR | 3451399
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ribas do rio pardo
# -------------------------------------------------------------------------------
# Processing: Record #  110  |  Alofi ,  NU | 4036284
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=alofi
# -------------------------------------------------------------------------------
# Processing: Record #  111  |  Jamestown ,  AU | 2069194
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=jamestown
# -------------------------------------------------------------------------------
# Processing: Record #  112  |  Jumla ,  NP | 1283285
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=jumla
# -------------------------------------------------------------------------------
# Processing: Record #  113  |  Saint-Philippe ,  CA | 6138908
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=saint-philippe
# -------------------------------------------------------------------------------
# Processing: Record #  114  |  Saint George ,  GR | 262462
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=saint george
# -------------------------------------------------------------------------------
# Processing: Record #  115  |  Yellowknife ,  CA | 6185377
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=yellowknife
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  116  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=bengkulu
# -------------------------------------------------------------------------------
# Processing: Record #  117  |  Sompeta ,  IN | 1255816
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=sompeta
# -------------------------------------------------------------------------------
# Processing: Record #  118  |  Kununurra ,  AU | 2068110
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kununurra
# -------------------------------------------------------------------------------
# Processing: Record #  119  |  Pointe Michel ,  DM | 3575660
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=pointe michel
# -------------------------------------------------------------------------------
# Processing: Record #  120  |  Mar del Plata ,  AR | 3863379
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mar del plata
# -------------------------------------------------------------------------------
# Processing: Record #  121  |  San Rafael del Sur ,  NI | 3616594
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=san rafael del sur
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  122  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=attawapiskat
# -------------------------------------------------------------------------------
# Processing: Record #  123  |  Geraldton ,  CA | 5960603
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=geraldton
# -------------------------------------------------------------------------------
# Processing: Record #  124  |  Kodiak ,  US | 4407665
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kodiak
# -------------------------------------------------------------------------------
# Processing: Record #  125  |  Sorland ,  NO | 3137469
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=sorland
# -------------------------------------------------------------------------------
# Processing: Record #  126  |  Riyadh ,  SA | 108410
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=riyadh
# -------------------------------------------------------------------------------
# Processing: Record #  127  |  Durban ,  FR | 3016194
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=durban
# -------------------------------------------------------------------------------
# Processing: Record #  128  |  Tilichiki ,  RU | 2120591
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=tilichiki
# -------------------------------------------------------------------------------
# Processing: Record #  129  |  Monrovia ,  LR | 2274895
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=monrovia
# -------------------------------------------------------------------------------
# Processing: Record #  130  |  Hualmay ,  PE | 3939761
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hualmay
# -------------------------------------------------------------------------------
# Processing: Record #  131  |  Tortoli ,  IT | 2522890
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=tortoli
# -------------------------------------------------------------------------------
# Processing: Record #  132  |  Ichinoseki ,  JP | 2112656
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ichinoseki
# -------------------------------------------------------------------------------
# Processing: Record #  133  |  Kruisfontein ,  ZA | 986717
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kruisfontein
# -------------------------------------------------------------------------------
# Processing: Record #  134  |  Igarka ,  RU | 1505991
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=igarka
# -------------------------------------------------------------------------------
# Processing: Record #  135  |  Garden City ,  US | 5118226
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=garden city
# -------------------------------------------------------------------------------
# Processing: Record #  136  |  Sambava ,  MG | 1056899
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=sambava
# -------------------------------------------------------------------------------
# Processing: Record #  137  |  Kalemie ,  CD | 214974
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kalemie
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  138  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=milingimbi
# -------------------------------------------------------------------------------
# Processing: Record #  139  |  Yurimaguas ,  PE | 3690654
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=yurimaguas
# -------------------------------------------------------------------------------
# Processing: Record #  140  |  Campo Grande ,  BR | 3467747
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=campo grande
# -------------------------------------------------------------------------------
# Processing: Record #  141  |  Calahorra ,  ES | 3127065
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=calahorra
# -------------------------------------------------------------------------------
# Processing: Record #  142  |  Plettenberg Bay ,  ZA | 964712
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=plettenberg bay
# -------------------------------------------------------------------------------
# Processing: Record #  143  |  Brokopondo ,  SR | 3384482
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=brokopondo
# -------------------------------------------------------------------------------
# Processing: Record #  144  |  Mopipi ,  BW | 933288
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mopipi
# -------------------------------------------------------------------------------
# Processing: Record #  145  |  Ahuimanu ,  US | 5856516
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ahuimanu
# -------------------------------------------------------------------------------
# Processing: Record #  146  |  Minab ,  IR | 123941
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=minab
# -------------------------------------------------------------------------------
# Processing: Record #  147  |  Arraial do Cabo ,  BR | 3471451
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=arraial do cabo
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  148  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=asau
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  149  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mys shmidta
# -------------------------------------------------------------------------------
# Processing: Record #  150  |  Aykino ,  RU | 580182
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=aykino
# -------------------------------------------------------------------------------
# Processing: Record #  151  |  Motril ,  ES | 2513477
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=motril
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  152  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=maarianhamina
# -------------------------------------------------------------------------------
# Processing: Record #  153  |  Los Llanos de Aridane ,  ES | 2514651
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=los llanos de aridane
# -------------------------------------------------------------------------------
# Processing: Record #  154  |  Ayr ,  GB | 2656708
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ayr
# -------------------------------------------------------------------------------
# Processing: Record #  155  |  Wenling ,  CN | 1791464
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=wenling
# -------------------------------------------------------------------------------
# Processing: Record #  156  |  Upernavik ,  GL | 3418910
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=upernavik
# -------------------------------------------------------------------------------
# Processing: Record #  157  |  Harper ,  US | 4696310
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=harper
# -------------------------------------------------------------------------------
# Processing: Record #  158  |  Provideniya ,  RU | 4031574
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=provideniya
# -------------------------------------------------------------------------------
# Processing: Record #  159  |  Richards Bay ,  ZA | 962367
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=richards bay
# -------------------------------------------------------------------------------
# Processing: Record #  160  |  Ketchikan ,  US | 5554428
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ketchikan
# -------------------------------------------------------------------------------
# Processing: Record #  161  |  Kaitangata ,  NZ | 2208248
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kaitangata
# -------------------------------------------------------------------------------
# Processing: Record #  162  |  Vestmannaeyjar ,  IS | 3412093
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=vestmannaeyjar
# -------------------------------------------------------------------------------
# Processing: Record #  163  |  Azzano Decimo ,  IT | 3182608
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=azzano decimo
# -------------------------------------------------------------------------------
# Processing: Record #  164  |  Sitka ,  US | 4267710
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=sitka
# -------------------------------------------------------------------------------
# Processing: Record #  165  |  Benemerito de las Americas ,  MX | 3816362
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=benemerito de las americas
# -------------------------------------------------------------------------------
# Processing: Record #  166  |  Dikson ,  RU | 1507390
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=dikson
# -------------------------------------------------------------------------------
# Processing: Record #  167  |  Grand-Lahou ,  CI | 2288105
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=grand-lahou
# -------------------------------------------------------------------------------
# Processing: Record #  168  |  East London ,  ZA | 1006984
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=east london
# -------------------------------------------------------------------------------
# Processing: Record #  169  |  Labuhan ,  ID | 1641899
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=labuhan
# -------------------------------------------------------------------------------
# Processing: Record #  170  |  Kolondieba ,  ML | 2454934
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kolondieba
# -------------------------------------------------------------------------------
# Processing: Record #  171  |  Port Blair ,  IN | 1259385
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=port blair
# -------------------------------------------------------------------------------
# Processing: Record #  172  |  Kavaratti ,  IN | 1267390
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kavaratti
# -------------------------------------------------------------------------------
# Processing: Record #  173  |  Albion ,  US | 5062806
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=albion
# -------------------------------------------------------------------------------
# Processing: Record #  174  |  Laguna ,  MX | 4013704
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=laguna
# -------------------------------------------------------------------------------
# Processing: Record #  175  |  Wasilla ,  US | 5877641
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=wasilla
# -------------------------------------------------------------------------------
# Processing: Record #  176  |  Wilmington ,  US | 4145381
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=wilmington
# -------------------------------------------------------------------------------
# Processing: Record #  177  |  Kaohsiung ,  TW | 1673820
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kaohsiung
# -------------------------------------------------------------------------------
# Processing: Record #  178  |  Dauphin ,  CA | 5935341
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=dauphin
# -------------------------------------------------------------------------------
# Processing: Record #  179  |  Gouyave ,  GD | 3580279
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=gouyave
# -------------------------------------------------------------------------------
# Processing: Record #  180  |  Ponta do Sol ,  BR | 3453439
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ponta do sol
# -------------------------------------------------------------------------------
# Processing: Record #  181  |  Huilong ,  CN | 1795424
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=huilong
# -------------------------------------------------------------------------------
# Processing: Record #  182  |  Semiletka ,  RU | 497211
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=semiletka
# -------------------------------------------------------------------------------
# Processing: Record #  183  |  Lagoa ,  PT | 2267254
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=lagoa
# -------------------------------------------------------------------------------
# Processing: Record #  184  |  Solnechnyy ,  RU | 2016307
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=solnechnyy
# -------------------------------------------------------------------------------
# Processing: Record #  185  |  Akdepe ,  TM | 601551
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=akdepe
# -------------------------------------------------------------------------------
# Processing: Record #  186  |  Fort Nelson ,  CA | 5955902
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=fort nelson
# -------------------------------------------------------------------------------
# Processing: Record #  187  |  Ostrovnoy ,  RU | 556268
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ostrovnoy
# -------------------------------------------------------------------------------
# Processing: Record #  188  |  Waitati ,  NZ | 2179825
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=waitati
# -------------------------------------------------------------------------------
# Processing: Record #  189  |  San Antonio ,  CL | 3872395
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=san antonio
# -------------------------------------------------------------------------------
# Processing: Record #  190  |  Lethem ,  GY | 3379316
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=lethem
# -------------------------------------------------------------------------------
# Processing: Record #  191  |  Kutum ,  SD | 371745
# ...
# Processing: Record #  541  |  Brae ,  GB | 2654970
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=brae
# -------------------------------------------------------------------------------
# Processing: Record #  542  |  Bereznik ,  RU | 577240
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=bereznik
# -------------------------------------------------------------------------------
# Processing: Record #  543  |  Mlonggo ,  ID | 1635164
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mlonggo
# -------------------------------------------------------------------------------
# Processing: Record #  544  |  Vega de Alatorre ,  MX | 3514843
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=vega de alatorre
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  545  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=saleaula
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  546  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=grand river south east
# -------------------------------------------------------------------------------
# Processing: Record #  547  |  Caxito ,  BR | 3451261
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=caxito
# -------------------------------------------------------------------------------
# Processing: Record #  548  |  Kupino ,  RU | 1501365
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kupino
# -------------------------------------------------------------------------------
# Processing: Record #  549  |  Port-Cartier ,  CA | 6111696
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=port-cartier
# -------------------------------------------------------------------------------
# Processing: Record #  550  |  Kashima ,  JP | 1859941
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kashima
# -------------------------------------------------------------------------------
# Processing: Record #  551  |  Marovoay ,  MG | 1059507
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=marovoay
# -------------------------------------------------------------------------------
# Processing: Record #  552  |  Marsh Harbour ,  BS | 3571913
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=marsh harbour
# -------------------------------------------------------------------------------
# Processing: Record #  553  |  Santa Rosa ,  AR | 3835994
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=santa rosa
# -------------------------------------------------------------------------------
# Processing: Record #  554  |  Champerico ,  MX | 3530097
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=champerico
# -------------------------------------------------------------------------------
# Processing: Record #  555  |  Warrensburg ,  US | 4413595
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=warrensburg
# -------------------------------------------------------------------------------
# Processing: Record #  556  |  Corrente ,  BR | 3445459
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=corrente
# -------------------------------------------------------------------------------
# Processing: Record #  557  |  Marquette ,  US | 5000947
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=marquette
# -------------------------------------------------------------------------------
# Processing: Record #  558  |  Ambilobe ,  MG | 1082243
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ambilobe
# -------------------------------------------------------------------------------
# Processing: Record #  559  |  San Angelo ,  US | 5530022
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=san angelo
# -------------------------------------------------------------------------------
# Processing: Record #  560  |  Naze ,  NG | 2337542
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=naze
# -------------------------------------------------------------------------------
# Processing: Record #  561  |  Lhokseumawe ,  ID | 1214658
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=lhokseumawe
# -------------------------------------------------------------------------------
# Processing: Record #  562  |  Cotacachi ,  EC | 3658781
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=cotacachi
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  563  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=gorno-chuyskiy
# -------------------------------------------------------------------------------
# Processing: Record #  564  |  Trinidad ,  UY | 3439749
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=trinidad
# -------------------------------------------------------------------------------
# Processing: Record #  565  |  Patacamaya ,  BO | 3908339
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=patacamaya
# -------------------------------------------------------------------------------
# Processing: Record #  566  |  Sumbe ,  AO | 3346015
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=sumbe
# -------------------------------------------------------------------------------
# Processing: Record #  567  |  Mindelo ,  PT | 2739997
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mindelo
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  568  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=maloshuyka
# -------------------------------------------------------------------------------
# Processing: Record #  569  |  Pierre ,  US | 5767918
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=pierre
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  570  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=tahta
# -------------------------------------------------------------------------------
# Processing: Record #  571  |  Eucaliptus ,  BO | 3902685
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=eucaliptus
# -------------------------------------------------------------------------------
# Processing: Record #  572  |  Rach Gia ,  VN | 1568510
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=rach gia
# -------------------------------------------------------------------------------
# Processing: Record #  573  |  Antofagasta ,  CL | 3899539
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=antofagasta
# -------------------------------------------------------------------------------
# Processing: Record #  574  |  Arlit ,  NE | 2447513
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=arlit
# -------------------------------------------------------------------------------
# Processing: Record #  575  |  Qeshm ,  IR | 119374
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=qeshm
# -------------------------------------------------------------------------------
# Processing: Record #  576  |  Marzuq ,  YE | 72181
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=marzuq
# -------------------------------------------------------------------------------
# Processing: Record #  577  |  Kintinku ,  TZ | 157247
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kintinku
# -------------------------------------------------------------------------------
# Processing: Record #  578  |  Shingu ,  JP | 1847947
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=shingu
# -------------------------------------------------------------------------------
# Processing: Record #  579  |  Te Anau ,  NZ | 2181625
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=te anau
# -------------------------------------------------------------------------------
# Processing: Record #  580  |  Khorramabad ,  IR | 127349
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=khorramabad
# -------------------------------------------------------------------------------
# Processing: Record #  581  |  Beringovskiy ,  RU | 2126710
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=beringovskiy
# -------------------------------------------------------------------------------
# Processing: Record #  582  |  Raymond ,  US | 5091636
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=raymond
# -------------------------------------------------------------------------------
# Processing: Record #  583  |  Saint-Pierre ,  FR | 2995603
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=saint-pierre
# -------------------------------------------------------------------------------
# Processing: Record #  584  |  San Jose ,  PH | 1689431
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=san jose
# -------------------------------------------------------------------------------
# Processing: Record #  585  |  Peleduy ,  RU | 2018069
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=peleduy
# -------------------------------------------------------------------------------
# Processing: Record #  586  |  Ulladulla ,  AU | 2145554
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ulladulla
# -------------------------------------------------------------------------------
# Processing: Record #  587  |  Batemans Bay ,  AU | 2176639
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=batemans bay
# -------------------------------------------------------------------------------
# Processing: Record #  588  |  Mindelheim ,  DE | 2871045
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=mindelheim
# -------------------------------------------------------------------------------
# Processing: Record #  589  |  Kyshtovka ,  RU | 1501000
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=kyshtovka
# -------------------------------------------------------------------------------
# Processing: Record #  590  |  Ginir ,  ET | 336454
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=ginir
# -------------------------------------------------------------------------------
# Processing: Record #  591  |  Srandakan ,  ID | 1626493
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=srandakan
# -------------------------------------------------------------------------------
# Processing: Record #  592  |  Hilton Head Island ,  US | 4581833
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=hilton head island
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  593  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=cheuskiny
# -------------------------------------------------------------------------------
# Processing: Record #  594  |  Guerrero Negro ,  MX | 4021858
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=guerrero negro
# -------------------------------------------------------------------------------
# Processing: Record #  595  |  Coari ,  BR | 3664539
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=coari
# No city record found. Skipping...
# -------------------------------------------------------------------------------
# Processing: Record #  596  |   City name not found (N/A)
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=haibowan
# -------------------------------------------------------------------------------
# Processing: Record #  597  |  Beaverlodge ,  CA | 5896969
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=beaverlodge
# -------------------------------------------------------------------------------
# Processing: Record #  598  |  Rudnyy ,  KZ | 1519843
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=rudnyy
# -------------------------------------------------------------------------------
# Processing: Record #  599  |  Wladyslawowo ,  PL | 3081752
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=wladyslawowo
# -------------------------------------------------------------------------------
# Processing: Record #  600  |  Maceio ,  BR | 3395981
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=maceio
# -------------------------------------------------------------------------------
# Processing: Record #  601  |  North Battleford ,  CA | 6089404
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=north battleford
# -------------------------------------------------------------------------------
# Processing: Record #  602  |  Muncar ,  ID | 1634718
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=muncar
# -------------------------------------------------------------------------------
# Processing: Record #  603  |  Forbes ,  AU | 2166368
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5f39cc686b8b2767cd7e816de10d16c0&q=forbes
# ---------------------------------------------------
# Data Retrieval Complete
# ---------------------------------------------------

# %%
weather = {
    "City": city_name,
    "Country": country,
    "Latitude": lat,
    "Temperature (F)": temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "WindSpeed": windspeed
}

weather_data = pd.DataFrame(weather)
weather_data.count()

# %%
weather_data.head()
